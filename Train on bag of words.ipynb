# %%
import pandas as pd 
from nltk.corpus import stopwords
# load nltk's SnowballStemmer as variabled 'stemmer'
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")

# %%
import pandas as pd
essay_set_1 = pd.read_csv('essay_set_1.csv')
essay_set_2 = pd.read_csv('essay_set_2.csv')
essay_set_3 = pd.read_csv('essay_set_3.csv')
essay_set_4 = pd.read_csv('essay_set_4.csv')
essay_set_5 = pd.read_csv('essay_set_5.csv')
essay_set_6 = pd.read_csv('essay_set_6.csv')
essay_set_7 = pd.read_csv('essay_set_7.csv')
essay_set_8 = pd.read_csv('essay_set_8.csv')
essay_set_9 = pd.read_csv('essay_set_9.csv')
essay_set_10 = pd.read_csv('essay_set_10.csv')

# %%
essay_set_1.head()
# Out:
#    Unnamed: 0  essay_id  essay_set  \
# 0           0         1          1
# 1           1         2          1
# 2           2         3          1
# 3           3         4          1
# 4           4         5          1
#
#                                                essay  rater1_domain1  \
# 0  Dear local newspaper, I think effects computer...             4.0
# 1  Dear @CAPS1 @CAPS2, I believe that using compu...             5.0
# 2  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...             4.0
# 3  Dear Local Newspaper, @CAPS1 I have found that...             5.0
# 4  Dear @LOCATION1, I know having computers has a...             4.0
#
#    rater2_domain1  domain1_score
# 0             4.0            8.0
# 1             4.0            9.0
# 2             3.0            7.0
# 3             5.0           10.0
# 4             4.0            8.0

# %%
essay_set_1_1 = essay_set_1[['essay','rater1_domain1']]
essay_set_2_1 = essay_set_2[['essay','rater1_domain1']]
essay_set_3_1 = essay_set_3[['essay','rater1_domain1']]
essay_set_4_1 = essay_set_4[['essay','rater1_domain1']]
essay_set_5_1 = essay_set_5[['essay','rater1_domain1']]
essay_set_6_1 = essay_set_6[['essay','rater1_domain1']]
essay_set_7_1 = essay_set_7[['essay','rater1_domain1']]
essay_set_8_1 = essay_set_8[['essay','rater1_domain1']]
essay_set_9_1 = essay_set_9[['essay','rater1_domain1']]
essay_set_10_1 = essay_set_10[['essay','rater1_domain1']]

# %%
essay_set_1_1.to_csv("essay_set_1_1.csv", index=False)
essay_set_2_1.to_csv("essay_set_2_1.csv", index=False)
essay_set_3_1.to_csv("essay_set_3_1.csv", index=False)
essay_set_4_1.to_csv("essay_set_4_1.csv", index=False)
essay_set_5_1.to_csv("essay_set_5_1.csv", index=False)
essay_set_6_1.to_csv("essay_set_6_1.csv", index=False)
essay_set_7_1.to_csv("essay_set_7_1.csv", index=False)
essay_set_8_1.to_csv("essay_set_8_1.csv", index=False)
essay_set_9_1.to_csv("essay_set_9_1.csv", index=False)
essay_set_10_1.to_csv("essay_set_10_1.csv", index=False)

# %%
essay_set_1_1.head()
# Out:
#                                                essay  rater1_domain1
# 0  Dear local newspaper, I think effects computer...             4.0
# 1  Dear @CAPS1 @CAPS2, I believe that using compu...             5.0
# 2  Dear, @CAPS1 @CAPS2 @CAPS3 More and more peopl...             4.0
# 3  Dear Local Newspaper, @CAPS1 I have found that...             5.0
# 4  Dear @LOCATION1, I know having computers has a...             4.0

# %%
stop = stopwords.words('english')

# %%
filtered_word_list = Set_1[:] #make a copy of the word_list
for word in Set_1: # iterate over word_list
  if word in stopwords.words('english'): 
    filtered_word_list.remove(word)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e2df91fe9cff> in <module>()
# ----> 1 filtered_word_list = Set_1[:] #make a copy of the word_list
#       2 for word in Set_1: # iterate over word_list
#       3   if word in stopwords.words('english'):
#       4     filtered_word_list.remove(word)
#
# NameError: name 'Set_1' is not defined

# %%
print(len(filtered_word_list))
print(len(Set_1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2bf12647fa25> in <module>()
# ----> 1 print(len(filtered_word_list))
#       2 print(len(Set_1))
#
# NameError: name 'filtered_word_list' is not defined

# %%
essay_set_1_1['essay'] = essay_set_1_1['essay'].str.lower().str.split()
essay_set_1_1['essay'] = essay_set_1_1['essay'].apply(lambda x: [item for item in string.split(x) if item not in stop])
# Out:
# /Users/Sarthak/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/Sarthak/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
essay_set_1_1[1:]
# Out:
#                                                   essay  rater1_domain1
# 1     [dear, @caps1, @caps2,, believe, using, comput...             5.0
# 2     [dear,, @caps1, @caps2, @caps3, people, use, c...             4.0
# 3     [dear, local, newspaper,, @caps1, found, many,...             5.0
# 4     [dear, @location1,, know, computers, positive,...             4.0
# 5     [dear, @location1,, think, computers, negative...             4.0
# 6     [know, people, days, depending, computers, saf...             5.0
# 7     [@percent1, people, agree, computers, make, li...             5.0
# 8     [dear, reader,, @organization1, dramatic, effe...             4.0
# 9     [@location1, technology, computer., say, compu...             5.0
# 10    [dear, @location1,, @caps1, people, acknowledg...             4.0
# 11    [dear, @caps1, @caps2, feel, computers, take, ...             4.0
# 12    [dear, local, newspaper, raed, ur, argument, c...             4.0
# ...

# %%
import numpy as np
from sklearn.model_selection import train_test_split

train, test = train_test_split(essay_set_1_1, test_size = 0.2)
print(train)
# Out:
#                                                   essay  rater1_domain1
# 1078  [dear, @location1, @caps1,, think, computers, ...             4.0
# 56    [@date1, become, far, advanced., computers, on...             5.0
# 815   [dear, @caps1,, @caps2, think, computers, bad,...             4.0
# 847   [dear, local, newspaper,, ever, thought, compu...             5.0
# 1451  [would, like, got, "@caps1", social, studies, ...             5.0
# 197   [dear, local, newspaper, @caps1,, @caps2, show...             5.0
# 610   [dear, @caps1,, @caps2, people, using, technol...             4.0
# 1626  [believe, computers, great, invention., lets, ...             4.0
# 907   [@organization1,, @date1, computers, help, man...             4.0
# 638   [opinion, people, spend, much, time, computers...             4.0
# 1270  [dear, @organization1,, understand, experts, s...             3.0
# 1298  [dear, local, newspaper, subject, computers;, ...             3.0
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the "CountVectorizer" object, which is scikit-learn's
# bag of words tool.  
vectorizer = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000) 

# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.
train_data_features = vectorizer.fit_transform(train)

# Numpy arrays are easy to work with, so convert the result to an 
# array
train_data_features = train_data_features.toarray()

# %%
print(train_data_features.shape)
# Out:
# (2, 2)

# %%
 #Take a look at the words in the vocabulary
vocab = vectorizer.get_feature_names()
print(vocab)
# Out:
# ['essay', 'rater1_domain1']
